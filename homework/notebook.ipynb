# %% [markdown]
# ```
# Column     Description                                             Feature Type
# ---------------------------------------------------------------------------------
# Age        Age in years                                            Numerical
# Sex        (1 = male; 0 = female)                                  Categorical
# CP         Chest pain type (0, 1, 2, 3, 4)                         Categorical
# Trestbpd   Resting blood pressure (in mm Hg on admission)          Numerical
# Chol       Serum cholesterol in mg/dl                              Numerical
# FBS        fasting blood sugar in 120 mg/dl (1 = true; 0 = false)  Categorical
# RestECG    Resting electrocardiogram results (0, 1, 2)             Categorical
# Thalach    Maximum heart rate achieved                             Numerical
# Exang      Exercise induced angina (1 = yes; 0 = no)               Categorical
# Oldpeak    ST depression induced by exercise relative to rest      Numerical
# Slope      Slope of the peak exercise ST segment                   Numerical
# CA         Number of major vessels (0-3) colored by fluoroscopy    Categorical
# Thal       3 = normal; 6 = fixed defect; 7 = reversible defect     Categorical
# Target     Diagnosis of heart disease (1 = true; 0 = false)        Target
# ```

# %%
def load_data():

    import pandas as pd

    dataset = pd.read_csv("../files/input/heart_disease.csv")
    y = dataset.pop("target")
    x = dataset.copy()
    x["thal"] = x["thal"].map(
        lambda x: "normal" if x not in ["fixed", "fixed", "reversible"] else x
    )

    return x, y


x, y = load_data()
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   52    1   1       118   186    0        2      190      0      0.0
# 299   43    0   4       132   341    1        2      136      1      3.0
# 300   65    1   4       135   254    0        2      127      0      2.8
# 301   48    1   4       130   256    1        2      150      1      0.0
# 302   63    0   4       150   407    0        2      154      0      4.0
#
#      slope  ca        thal
# 0        3   0       fixed
# 1        2   3      normal
# 2        2   2  reversible
# 3        3   0      normal
# 4        1   0      normal
# ..     ...  ..         ...
# 298      2   0       fixed
# 299      2   0  reversible
# 300      2   1  reversible
# 301      1   2  reversible
# 302      2   3  reversible
#
# [303 rows x 13 columns]

# %%
def make_train_test_split(x, y):

    from sklearn.model_selection import train_test_split

    (x_train, x_test, y_train, y_test) = train_test_split(
        x,
        y,
        test_size=0.10,
        random_state=0,
    )
    return x_train, x_test, y_train, y_test

# %%
def make_pipeline(estimator):

    from sklearn.compose import ColumnTransformer
    from sklearn.feature_selection import SelectKBest, f_classif
    from sklearn.pipeline import Pipeline
    from sklearn.preprocessing import OneHotEncoder

    transformer = ColumnTransformer(
        transformers=[
            ("ohe", OneHotEncoder(dtype="int"), ["thal"]),
        ],
        remainder="passthrough",
    )

    selectkbest = SelectKBest(score_func=f_classif)

    pipeline = Pipeline(
        steps=[
            ("tranformer", transformer),
            ("selectkbest", selectkbest),
            ("estimator", estimator),
        ],
        verbose=False,
    )

    return pipeline

# %%
def make_grid_search(estimator, param_grid, cv=5):

    from sklearn.model_selection import GridSearchCV

    grid_search = GridSearchCV(
        estimator=estimator,
        param_grid=param_grid,
        cv=cv,
        scoring="balanced_accuracy",
    )

    return grid_search

# %%
def save_estimator(estimator):

    import pickle

    with open("estimator.pickle", "wb") as file:
        pickle.dump(estimator, file)

# %%
def load_estimator():

    import os
    import pickle

    if not os.path.exists("estimator.pickle"):
        return None
    with open("estimator.pickle", "rb") as file:
        estimator = pickle.load(file)

    return estimator

# %%
def train_estimator(estimator):


    from sklearn.metrics import mean_absolute_error

    data, target = load_data()

    x_train, x_test, y_train, y_test = make_train_test_split(
        x=data,
        y=target,
    )

    estimator.fit(x_train, y_train)

    best_estimator = load_estimator()

    if best_estimator is not None:

        saved_mae = mean_absolute_error(
            y_true=y_test, y_pred=best_estimator.predict(x_test)
        )

        current_mae = mean_absolute_error(
            y_true=y_test, y_pred=estimator.predict(x_test)
        )

        if saved_mae < current_mae:
            estimator = best_estimator

    save_estimator(estimator)

# %%
def train_logistic_regression():

    from sklearn.linear_model import LogisticRegression

    pipeline = make_pipeline(
        estimator=LogisticRegression(max_iter=10000, solver="saga"),
    )

    param_grid = {
        "selectkbest__k": range(1, 11),
        "estimator__penalty": ["l1", "l2"],
        "estimator__C": [0.001, 0.01, 0.1, 1, 10, 100],
    }

    estimator = make_grid_search(
        estimator=pipeline,
        param_grid=param_grid,
        cv=5,
    )

    train_estimator(estimator)


train_logistic_regression()

# %%
def eval_metrics(
    y_train_true,
    y_test_true,
    y_train_pred,
    y_test_pred,
):

    from sklearn.metrics import accuracy_score, balanced_accuracy_score

    accuracy_train = round(accuracy_score(y_train_true, y_train_pred), 4)
    accuracy_test = round(accuracy_score(y_test_true, y_test_pred), 4)
    balanced_accuracy_train = round(
        balanced_accuracy_score(y_train_true, y_train_pred), 4
    )
    balanced_accuracy_test = round(balanced_accuracy_score(y_test_true, y_test_pred), 4)

    return (
        accuracy_train,
        accuracy_test,
        balanced_accuracy_train,
        balanced_accuracy_test,
    )

# %%
def report(
    estimator,
    accuracy_train,
    accuracy_test,
    balanced_accuracy_train,
    balanced_accuracy_test,
):

    print(estimator, ":", sep="")
    print("-" * 80)
    print(f"Balanced Accuracy: {balanced_accuracy_test} ({balanced_accuracy_train})")
    print(f"         Accuracy: {accuracy_test} ({accuracy_train})")

# %%
def check_estimator():

    import pickle

    import pandas as pd
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    data, target = load_data()

    x_train, x_test, y_train_true, y_test_true = make_train_test_split(
        x=data,
        y=target,
    )

    estimator = load_estimator()

    y_train_pred = estimator.predict(x_train)
    y_test_pred = estimator.predict(x_test)

    (
        accuracy_train,
        accuracy_test,
        balanced_accuracy_train,
        balanced_accuracy_test,
    ) = eval_metrics(
        y_train_true,
        y_test_true,
        y_train_pred,
        y_test_pred,
    )

    report(
        estimator.best_estimator_,
        accuracy_train,
        accuracy_test,
        balanced_accuracy_train,
        balanced_accuracy_test,
    )


check_estimator()
# Out:
# Pipeline(steps=[('tranformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(dtype='int'),
#                                                   ['thal'])])),
#                 ('selectkbest', SelectKBest(k=6)),
#                 ('estimator',
#                  LogisticRegression(C=10, max_iter=10000, penalty='l1',
#                                     solver='saga'))]):
# --------------------------------------------------------------------------------
# Balanced Accuracy: 0.6368 (0.8296)
#          Accuracy: 0.6774 (0.8787)

# %%
def train_mlp_classifier():

    from sklearn.neural_network import MLPClassifier

    pipeline = make_pipeline(
        estimator=MLPClassifier(max_iter=10000),
    )

    param_grid = {
        "selectkbest__k": range(1, 11),
        "estimator__hidden_layer_sizes": [(h,) for h in range(1, 11)],
        "estimator__learning_rate_init": [0.0001, 0.001, 0.01, 0.1, 1.0],
    }

    estimator = make_grid_search(
        estimator=pipeline,
        param_grid=param_grid,
        cv=5,
    )

    train_estimator(estimator)


train_mlp_classifier()
check_estimator()
# Out:
# c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:628, in BaseMultilayerPerceptron._fit_stochastic(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units, incremental)
#     627     X_batch = _safe_indexing(X, sample_idx[batch_slice])
# --> 628     y_batch = y[sample_idx[batch_slice]]
#     629 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 24
#      15     estimator = make_grid_search(
#      16         estimator=pipeline,
#      17         param_grid=param_grid,
#      18         cv=5,
#      19     )
#      21     train_estimator(estimator)
# ---> 24 train_mlp_classifier()
#      25 check_estimator()
#
# Cell In[17], line 21, in train_mlp_classifier()
#       9 param_grid = {
#      10     "selectkbest__k": range(1, 11),
#      11     "estimator__hidden_layer_sizes": [(h,) for h in range(1, 11)],
#      12     "estimator__learning_rate_init": [0.0001, 0.001, 0.01, 0.1, 1.0],
#      13 }
#      15 estimator = make_grid_search(
#      16     estimator=pipeline,
#      17     param_grid=param_grid,
#      18     cv=5,
#      19 )
# ---> 21 train_estimator(estimator)
#
# Cell In[12], line 13, in train_estimator(estimator)
#       6 data, target = load_data()
#       8 x_train, x_test, y_train, y_test = make_train_test_split(
#       9     x=data,
#      10     y=target,
#      11 )
# ---> 13 estimator.fit(x_train, y_train)
#      15 best_estimator = load_estimator()
#      17 if best_estimator is not None:
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\model_selection\_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\pipeline.py:662, in Pipeline.fit(self, X, y, **params)
#     656     if self._final_estimator != "passthrough":
#     657         last_step_params = self._get_metadata_for_step(
#     658             step_idx=len(self) - 1,
#     659             step_params=routed_params[self.steps[-1][0]],
#     660             all_params=params,
#     661         )
# --> 662         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     664 return self
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:754, in BaseMultilayerPerceptron.fit(self, X, y)
#     736 @_fit_context(prefer_skip_nested_validation=True)
#     737 def fit(self, X, y):
#     738     """Fit the model to data matrix X and target(s) y.
#     739
#     740     Parameters
#    (...)
#     752         Returns a trained MLP model.
#     753     """
# --> 754     return self._fit(X, y, incremental=False)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:476, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     474 # Run the Stochastic optimization solver
#     475 if self.solver in _STOCHASTIC_SOLVERS:
# --> 476     self._fit_stochastic(
#     477         X,
#     478         y,
#     479         activations,
#     480         deltas,
#     481         coef_grads,
#     482         intercept_grads,
#     483         layer_units,
#     484         incremental,
#     485     )
#     487 # Run the LBFGS solver
#     488 elif self.solver == "lbfgs":
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:698, in BaseMultilayerPerceptron._fit_stochastic(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units, incremental)
#     691             warnings.warn(
#     692                 "Stochastic Optimizer: Maximum iterations (%d) "
#     693                 "reached and the optimization hasn't converged yet."
#     694                 % self.max_iter,
#     695                 ConvergenceWarning,
#     696             )
#     697 except KeyboardInterrupt:
# --> 698     warnings.warn("Training interrupted by user.")
#     700 if early_stopping:
#     701     # restore best weights
#     702     self.coefs_ = self._best_coefs
#
# File ~\AppData\Local\Programs\Python\Python39\lib\warnings.py:112, in _showwarnmsg(msg)
#     109         sw(msg.message, msg.category, msg.filename, msg.lineno,
#     110            msg.file, msg.line)
#     111         return
# --> 112 _showwarnmsg_impl(msg)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\warnings.py:30, in _showwarnmsg_impl(msg)
#      28 text = _formatwarnmsg(msg)
#      29 try:
# ---> 30     file.write(text)
#      31 except OSError:
#      32     # the file (probably stderr) is invalid - this warning gets lost.
#      33     pass
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\ipykernel\iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\ipykernel\iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\zmq\backend\cython\_zmq.py:1152, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\zmq\backend\cython\_zmq.py:1200, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\zmq\backend\cython\_zmq.py:1468, in zmq.backend.cython._zmq._send_copy()
#
# File c:\Users\n_and\Documents\Analitica predictiva 2025 2\PRE-10-selectkbest-para-clasificacion-nsalinas350\.venv\lib\site-packages\zmq\backend\cython\_zmq.py:179, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:
